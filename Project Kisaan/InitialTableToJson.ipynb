# %%
import json
import sys

# %%
x_step = 500
x_max = 3000
y_step = 300
y_max = 1500

# %%
obj = {u"gas": '',u"humidity": '',u"temperature": '',u"x": 'NaN',u"y": 'NaN',u"time": ''}

# %%
obj
# Out:
# {'gas': '',
#  'humidity': '',
#  'temperature': '',
#  'x': 'NaN',
#  'y': 'NaN',
#  'time': ''}

# %%
x_n = int(x_max / x_step)
y_n = int(y_max / y_step)

# %%
data = []
for i in range(0,x_n):
    for j in range(0,y_n):
        data.append(obj)

# %%
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     },
#     {
#         "gas": "",
#         "humidity": "",
#         "temperature": "",
#         "x": "NaN",
#         "y": "NaN",
#         "time": ""
#     }
# ]

# %%
with open('data.json', 'w') as outfile:
    json.dump(data, outfile)
